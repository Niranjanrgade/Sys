# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Salary_Data.csv')
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
sns.pairplot(df)

# %%
x = df[["YearsExperience"]]
y = df['Salary']

# %%
from math import comb
split = 0.8
combinations = comb(len(x), int(split*len(x)))
combinations
# Out:
# 4272048

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
from sklearn.metrics import r2_score

combinations_dict = dict() 

for combination in range(combinations):
    x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=combination)
    model.fit(x_train, y_train) 
    combinations_dict[combination] = r2_score(y_test, model.predict(x_test))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [17], line 6
#       3 combinations_dict = dict()
#       5 for combination in range(combinations):
# ----> 6     x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=combination)
#       7     model.fit(x_train, y_train)
#       8     combinations_dict[combination] = r2_score(y_test, model.predict(x_test))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:2471, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2467     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2469     train, test = next(cv.split(X=arrays[0], y=stratify))
# -> 2471 return list(
#    2472     chain.from_iterable(
#    2473         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2474     )
#    2475 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:2473, in <genexpr>(.0)
#    2467     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2469     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2471 return list(
#    2472     chain.from_iterable(
# -> 2473         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2474     )
#    2475 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\__init__.py:359, in _safe_indexing(X, indices, axis)
#     353     raise ValueError(
#     354         "Specifying the columns using strings is only supported for "
#     355         "pandas DataFrames"
#     356     )
#     358 if hasattr(X, "iloc"):
# --> 359     return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     360 elif hasattr(X, "shape"):
#     361     return _array_indexing(X, indices, indices_dtype, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\__init__.py:201, in _pandas_indexing(X, key, key_dtype, axis)
#     196     key = list(key)
#     198 if key_dtype == "int" and not (isinstance(key, slice) or np.isscalar(key)):
#     199     # using take() instead of iloc[] ensures the return value is a "proper"
#     200     # copy that will not raise SettingWithCopyWarning
# --> 201     return X.take(key, axis=axis)
#     202 else:
#     203     # check whether we should index with loc or iloc
#     204     indexer = X.iloc if key_dtype == "int" else X.loc
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:3872, in NDFrame.take(self, indices, axis, is_copy, **kwargs)
#    3863     warnings.warn(
#    3864         "is_copy is deprecated and will be removed in a future version. "
#    3865         "'take' always returns a copy, so there is no need to specify this.",
#    3866         FutureWarning,
#    3867         stacklevel=find_stack_level(inspect.currentframe()),
#    3868     )
#    3870 nv.validate_take((), kwargs)
# -> 3872 return self._take(indices, axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:3887, in NDFrame._take(self, indices, axis, convert_indices)
#    3880 """
#    3881 Internal version of the `take` allowing specification of additional args.
#    3882
#    3883 See the docstring of `take` for full explanation of the parameters.
#    3884 """
#    3885 self._consolidate_inplace()
# -> 3887 new_data = self._mgr.take(
#    3888     indices,
#    3889     axis=self._get_block_manager_axis(axis),
#    3890     verify=True,
#    3891     convert_indices=convert_indices,
#    3892 )
#    3893 return self._constructor(new_data).__finalize__(self, method="take")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:968, in BaseBlockManager.take(self, indexer, axis, verify, convert_indices)
#     965 if convert_indices:
#     966     indexer = maybe_convert_indices(indexer, n, verify=verify)
# --> 968 new_labels = self.axes[axis].take(indexer)
#     969 return self.reindex_indexer(
#     970     new_axis=new_labels,
#     971     indexer=indexer,
#    (...)
#     974     copy=None,
#     975 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:1185, in Index.take(self, indices, axis, allow_fill, fill_value, **kwargs)
#    1183 values = self._values
#    1184 if isinstance(values, np.ndarray):
# -> 1185     taken = algos.take(
#    1186         values, indices, allow_fill=allow_fill, fill_value=self._na_value
#    1187     )
#    1188 else:
#    1189     # algos.take passes 'axis' keyword which not all EAs accept
#    1190     taken = values.take(
#    1191         indices, allow_fill=allow_fill, fill_value=self._na_value
#    1192     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\algorithms.py:1570, in take(arr, indices, axis, allow_fill, fill_value)
#    1565     result = take_nd(
#    1566         arr, indices, axis=axis, allow_fill=True, fill_value=fill_value
#    1567     )
#    1568 else:
#    1569     # NumPy style
# -> 1570     result = arr.take(indices, axis=axis)
#    1571 return result
#
# KeyboardInterrupt:

# %%
# Out:
# LinearRegression()

# %%
y_true = y_test
y_pred = model.predict(x_test)

# %%
plt.plot(x_test, y_pred)
plt.scatter(x, y)
