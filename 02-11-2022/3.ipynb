# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.linspace(-1, 1, 1000)**3

# %%
x = np.linspace(-1, 1, 1000)

# %%
plt.plot(x, y)
plt.plot(np.array([-1, 1]), np.array([-1, 1]))
plt.plot(np.array([0, 0]), np.array([-1, 1]))
plt.plot(np.array([-1, 1]), np.array([0, 0]))

# %%
plt.(np.array([x**5 for x in [-1, -0.75, -0.5, -0.25, 0, 0.25, 0.5, 0.75, 1]]))
