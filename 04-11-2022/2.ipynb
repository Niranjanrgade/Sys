# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
df = pd.read_csv('AirPassengers.csv')
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.shape
# Out:
# (144, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df['Month'] = pd.to_datetime(df['Month'], format='%Y-%m')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    datetime64[ns]
#  1   #Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
df.index = df['Month']
df.head()
# Out:
#                 Month  #Passengers
# Month
# 1949-01-01 1949-01-01          112
# 1949-02-01 1949-02-01          118
# 1949-03-01 1949-03-01          132
# 1949-04-01 1949-04-01          129
# 1949-05-01 1949-05-01          121

# %%
del df['Month']

# %%
df.plot()
# Out:
# <AxesSubplot: xlabel='Month'>

# %%
print(list(df.rolling(window=5)))
# Out:
# [            #Passengers
# Month
# 1949-01-01          112,             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118,             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132,             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129,             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121,             #Passengers
# Month
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# 1949-06-01          135,             #Passengers
# Month
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# 1949-06-01          135
# 1949-07-01          148,             #Passengers
# Month
# 1949-04-01          129
# 1949-05-01          121
# 1949-06-01          135
# ...
